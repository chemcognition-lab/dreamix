# %%
import pandas as pd

# %%
main_df = pd.read_csv("TrainingData_mixturedist.csv")
main_df.dropna(inplace=True)

mixture_df_1 = pd.read_csv("Mixture_Definitions_smi_Training_set.csv")
rename_dict = {}
i = 0
for col in mixture_df_1.columns:
    if col.startswith('smi'):
        rename_dict[col] = f'smi_{i}.1'
        i += 1

mixture_df_1.rename(columns=rename_dict, inplace=True)

rename_dict = {}

mixture_df_2 = mixture_df_1.copy()
for col in mixture_df_2.columns:
    if col.endswith('.1'):
        rename_dict[col] = col.replace('.1', '.2')

mixture_df_2.rename(columns=rename_dict, inplace=True)

# %%
main_df = pd.merge(main_df, mixture_df_1, left_on=['Dataset', 'Mixture 1'], right_on=["Dataset", "Mixture Label"], how='left')
main_df.drop('Mixture Label', axis=1, inplace=True)
main_df = pd.merge(main_df, mixture_df_2, left_on=['Dataset', 'Mixture 2'], right_on=["Dataset", "Mixture Label"], how='left')#
main_df.drop('Mixture Label', axis=1, inplace=True)

# %%
main_df.to_csv("../competition_train/competition_train_combined.csv", index=False)

# %%
list(main_df.columns[4:])
# Out:
# ['smi_0.1',
#  'smi_1.1',
#  'smi_2.1',
#  'smi_3.1',
#  'smi_4.1',
#  'smi_5.1',
#  'smi_6.1',
#  'smi_7.1',
#  'smi_8.1',
#  'smi_9.1',
#  'smi_10.1',
#  'smi_11.1',
#  'smi_12.1',
#  'smi_13.1',
#  'smi_14.1',
#  'smi_15.1',
#  'smi_16.1',
#  'smi_17.1',
#  'smi_18.1',
#  'smi_19.1',
#  'smi_20.1',
#  'smi_21.1',
#  'smi_22.1',
#  'smi_23.1',
#  'smi_24.1',
#  'smi_25.1',
#  'smi_26.1',
#  'smi_27.1',
#  'smi_28.1',
#  'smi_29.1',
#  'smi_30.1',
#  'smi_31.1',
#  'smi_32.1',
#  'smi_33.1',
#  'smi_34.1',
#  'smi_35.1',
#  'smi_36.1',
#  'smi_37.1',
#  'smi_38.1',
#  'smi_39.1',
#  'smi_40.1',
#  'smi_41.1',
#  'smi_42.1',
#  'smi_43.1',
#  'smi_44.1',
#  'smi_45.1',
#  'smi_46.1',
#  'smi_47.1',
#  'smi_48.1',
#  'smi_49.1',
#  'smi_50.1',
#  'smi_51.1',
#  'smi_52.1',
#  'smi_53.1',
#  'smi_54.1',
#  'smi_55.1',
#  'smi_56.1',
#  'smi_57.1',
#  'smi_0.2',
#  'smi_1.2',
#  'smi_2.2',
#  'smi_3.2',
#  'smi_4.2',
#  'smi_5.2',
#  'smi_6.2',
#  'smi_7.2',
#  'smi_8.2',
#  'smi_9.2',
# ...
